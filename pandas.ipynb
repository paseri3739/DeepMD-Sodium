# %%
import pandas as pd
df_original = pd.read_excel("7量体全異性体構造データ.xlsx")
# Out:
# /Users/masato/.pyenv/versions/3.11.4/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
display(df_original)
# Out:
#      iseitaiNo      x(1)      y(1)      z(1)      x(2)      y(2)      z(2)  \
# 0            1  3.175938  0.000000  0.642801  3.756630  0.731089  0.285909
# 1            2  2.460441  1.501044  0.790067  3.718295  1.167832  0.000000
# 2            3  1.407205  0.000000  0.977984  2.314596  1.577818  1.453934
# 3            4  0.639228  0.079437  0.000000  0.134869  0.000000  0.859928
# 4            5  0.670276  0.748851  1.196859  0.309054  1.416637  0.545777
# ..         ...       ...       ...       ...       ...       ...       ...
# 848        849  0.854726  1.169467  0.574081  0.592682  0.583734  1.146936
# 849        850  0.717077  1.196094  0.521371  0.718690  0.584011  1.236306
# 850        851  0.310999  1.203808  0.592185  1.126287  1.202979  0.592085
# 851        852  0.733255  0.650958  1.130573  0.322175  1.196684  0.566501
# 852        853  0.677721  0.602225  0.000000  0.000000  0.734171  0.560412
#
# ...

# %%
df_sliced = df_original.iloc[:, 1:22]
display(df_sliced)
# Out:
#          x(1)      y(1)      z(1)      x(2)      y(2)      z(2)      x(3)  \
# 0    3.175938  0.000000  0.642801  3.756630  0.731089  0.285909  3.093751
# 1    2.460441  1.501044  0.790067  3.718295  1.167832  0.000000  2.908746
# 2    1.407205  0.000000  0.977984  2.314596  1.577818  1.453934  2.477075
# 3    0.639228  0.079437  0.000000  0.134869  0.000000  0.859928  0.000000
# 4    0.670276  0.748851  1.196859  0.309054  1.416637  0.545777  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 848  0.854726  1.169467  0.574081  0.592682  0.583734  1.146936  0.000000
# 849  0.717077  1.196094  0.521371  0.718690  0.584011  1.236306  1.436654
# 850  0.310999  1.203808  0.592185  1.126287  1.202979  0.592085  0.000000
# 851  0.733255  0.650958  1.130573  0.322175  1.196684  0.566501  1.465821
# 852  0.677721  0.602225  0.000000  0.000000  0.734171  0.560412  0.593997
#
#          y(3)      z(3)      x(4)  ...      z(4)      x(5)      y(5)  \
# ...

# %%
df_resized = df_sliced * 3
display(df_resized)
# Out:
#          x(1)      y(1)      z(1)       x(2)      y(2)      z(2)      x(3)  \
# 0    9.527813  0.000000  1.928402  11.269891  2.193267  0.857727  9.281253
# 1    7.381322  4.503131  2.370200  11.154885  3.503495  0.000000  8.726237
# 2    4.221615  0.000000  2.933951   6.943787  4.733453  4.361803  7.431224
# 3    1.917684  0.238312  0.000000   0.404607  0.000000  2.579785  0.000000
# 4    2.010829  2.246553  3.590576   0.927163  4.249912  1.637332  0.000000
# ..        ...       ...       ...        ...       ...       ...       ...
# 848  2.564179  3.508401  1.722244   1.778046  1.751201  3.440808  0.000000
# 849  2.151231  3.588281  1.564113   2.156070  1.752034  3.708918  4.309963
# 850  0.932998  3.611423  1.776554   3.378861  3.608937  1.776254  0.000000
# 851  2.199764  1.952873  3.391719   0.966524  3.590051  1.699502  4.397462
# 852  2.033162  1.806674  0.000000   0.000000  2.202512  1.681235  1.781991
#
# ...

# %%
df_resized.to_csv("out.csv")
